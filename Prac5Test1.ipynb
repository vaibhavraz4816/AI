# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('diabetes.csv')

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
#cleaning
(df.isna()|df.empty|df.isnull()).sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
# Pregnancies                 768 non-null int64
# Glucose                     768 non-null int64
# BloodPressure               768 non-null int64
# SkinThickness               768 non-null int64
# Insulin                     768 non-null int64
# BMI                         768 non-null float64
# DiabetesPedigreeFunction    768 non-null float64
# Age                         768 non-null int64
# Outcome                     768 non-null int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df = df.rename(columns = {'Outcome' : 'target'})

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  target
# 0                       0.627   50       1
# ...

# %%
df['target'].value_counts()
# Out:
# 0    500
# 1    268
# Name: target, dtype: int64

# %%
df['target'] = df['target'].map({ 0 : 'No', 1 : 'Yes'})

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age target
# 0                     0.627   50    Yes
# 1                     0.351   31     No
# 2                     0.672   32    Yes
# 3                     0.167   21     No
# 4                     2.288   33    Yes

# %%
df['target'] = df['target'].map({'Yes' : 1, 'No' : 0})

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  target
# 0                       0.627   50       1
# ...

# %%
# print("Uniques values in column1",df['Pregnancies'].unique(),"\n")
# print("Uniques values in column2",df['Glucose'].unique(),"\n")
# print("Uniques values in column3",df['BloodPressure'].unique(),"\n")
# print("Uniques values in column4",df['SkinThickness'].unique(),"\n")
# print("Uniques values in column5",df['Insulin'].unique(),"\n")
# print("Uniques values in column6",df['BMI'].unique(),"\n")
# print("Uniques values in column7",df['DiabetesPedigreeFunction'].unique(),"\n")
# print("Uniques values in column8",df['Age'].unique(),"\n")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
# Pregnancies                 768 non-null int64
# Glucose                     768 non-null int64
# BloodPressure               768 non-null int64
# SkinThickness               768 non-null int64
# Insulin                     768 non-null int64
# BMI                         768 non-null float64
# DiabetesPedigreeFunction    768 non-null float64
# Age                         768 non-null int64
# target                      768 non-null int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
#standardization
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df2 = pd.DataFrame(scaler.fit_transform(df.loc[:,df.columns != 'target']),columns = df.columns[:-1])
df2['target'] = df['target']

# %%
df2.describe()
# Out:
#         Pregnancies       Glucose  BloodPressure  SkinThickness       Insulin  \
# count  7.680000e+02  7.680000e+02   7.680000e+02   7.680000e+02  7.680000e+02
# mean   2.544261e-17  3.614007e-18  -1.327244e-17   7.994184e-17 -3.556183e-17
# std    1.000652e+00  1.000652e+00   1.000652e+00   1.000652e+00  1.000652e+00
# min   -1.141852e+00 -3.783654e+00  -3.572597e+00  -1.288212e+00 -6.928906e-01
# 25%   -8.448851e-01 -6.852363e-01  -3.673367e-01  -1.288212e+00 -6.928906e-01
# 50%   -2.509521e-01 -1.218877e-01   1.496408e-01   1.545332e-01 -4.280622e-01
# 75%    6.399473e-01  6.057709e-01   5.632228e-01   7.190857e-01  4.120079e-01
# max    3.906578e+00  2.444478e+00   2.734528e+00   4.921866e+00  6.652839e+00
#
#                 BMI  DiabetesPedigreeFunction           Age      target
# count  7.680000e+02              7.680000e+02  7.680000e+02  768.000000
# mean   2.295979e-16              2.398978e-16  1.857600e-16    0.348958
# ...

# %%
# features
X = df2.drop('target',axis = 1)
# target
y = df['target']

# %%
X
# Out:
#      Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0       0.639947  0.848324       0.149641       0.907270 -0.692891  0.204013
# 1      -0.844885 -1.123396      -0.160546       0.530902 -0.692891 -0.684422
# 2       1.233880  1.943724      -0.263941      -1.288212 -0.692891 -1.103255
# 3      -0.844885 -0.998208      -0.160546       0.154533  0.123302 -0.494043
# 4      -1.141852  0.504055      -1.504687       0.907270  0.765836  1.409746
# ..           ...       ...            ...            ...       ...       ...
# 763     1.827813 -0.622642       0.356432       1.722735  0.870031  0.115169
# 764    -0.547919  0.034598       0.046245       0.405445 -0.692891  0.610154
# 765     0.342981  0.003301       0.149641       0.154533  0.279594 -0.735190
# 766    -0.844885  0.159787      -0.470732      -1.288212 -0.692891 -0.240205
# 767    -0.844885 -0.873019       0.046245       0.656358 -0.692891 -0.202129
#
#      DiabetesPedigreeFunction       Age
# ...

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: target, Length: 768, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.25,random_state = 42)

# %%
print("Shape of X train : ",X_train.shape)
print("Shape of X test : ",X_test.shape)
print("Shape of Y train : ",y_train.shape)
print("Shape of Y test : ",y_test.shape)
# Out:
# Shape of X train :  (576, 8)
# Shape of X test :  (192, 8)
# Shape of Y train :  (576,)
# Shape of Y test :  (192,)

# %%
#Decision Tree Classifier
from sklearn.tree import DecisionTreeClassifier
deci_tree = DecisionTreeClassifier(criterion = "gini")
deci_tree.fit(X_train,y_train)
y_pred = deci_tree.predict(X_test)

# %%
#Classification Metrics
from sklearn.metrics import confusion_matrix,precision_score,recall_score,f1_score,ConfusionMatrixDisplay
fig,(ax1) = plt.subplots()
fig.set_size_inches(15,5)
ax1.set_title('Confusion Matrix')
ConfusionMatrixDisplay.from_estimator(deci_tree,X_test,y_test,ax = ax1)

# %%
from sklearn.metrics import accuracy_score,classification_report
print("Accuracy of decision tree")
deci_score = accuracy_score(y_test,y_pred)
print("Decision tree accuracy : ",deci_score * 100 ,"%")

print("\n Classification report on the test data")
print(classification_report(y_test,y_pred))
# Out:
# Accuracy of decision tree
# Decision tree accuracy :  68.75 %
#
#  Classification report on the test data
#               precision    recall  f1-score   support
#
#            0       0.71      0.85      0.77       121
#            1       0.62      0.41      0.49        71
#
#     accuracy                           0.69       192
#    macro avg       0.66      0.63      0.63       192
# weighted avg       0.68      0.69      0.67       192

# %%
from sklearn import tree
fn = list(df2.columns[:-1])
cn = ['No','Yes']

fig , axes = plt.subplots(nrows = 1,ncols = 1 ,figsize = (8,8) ,dpi = 400)
tree.plot_tree (deci_tree ,feature_names = fn,class_names = cn,filled = True);
fig.savefig('MyDecitree.png')

# %%
# tree.plot_tree(deci_tree)

# %%
#naive bayse in holdout
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()
nb.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred = nb.predict(X_test)

# %%
fig , axes = plt.subplots(figsize = (15,5))
axes.set_title("Confusion Matrix")
ConfusionMatrixDisplay.from_estimator(nb,X_test,y_test,ax = axes)

# %%
print("Accuracy of Naive Bayes on test data")
nb_score = accuracy_score(y_test,y_pred)
print("Naive bayes accuracy : ",nb_score*100 ,"%")

print("\n Classification report on test data")
print(classification_report(y_test,y_pred))
# Out:
# Accuracy of Naive Bayes on test data
# Naive bayes accuracy :  73.4375 %
#
#  Classification report on test data
#               precision    recall  f1-score   support
#
#            0       0.81      0.76      0.79       123
#            1       0.62      0.68      0.65        69
#
#     accuracy                           0.73       192
#    macro avg       0.71      0.72      0.72       192
# weighted avg       0.74      0.73      0.74       192

# %%
#knn in holdout
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier()
knn.fit(X_train,y_train)
y_pred = knn.predict(X_test)

# %%
print("Accuracy of K Nearest Neighbours on test data")
knn_score = accuracy_score(y_test,y_pred)
print("Naive bayes accuracy : ",knn_score*100 ,"%")

print("\n Classification report on test data")
print(classification_report(y_test,y_pred))
# Out:
# Accuracy of K Nearest Neighbours on test data
# Naive bayes accuracy :  68.22916666666666 %
#
#  Classification report on test data
#               precision    recall  f1-score   support
#
#            0       0.74      0.77      0.76       123
#            1       0.56      0.52      0.54        69
#
#     accuracy                           0.68       192
#    macro avg       0.65      0.65      0.65       192
# weighted avg       0.68      0.68      0.68       192

# %%
#random subsampling
#decision tree
acc = []
deci_tree = DecisionTreeClassifier(criterion = "entropy")
for i in range(10):
    X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.25,random_state = i+1)
    deci_tree.fit(X_train,y_train)
    y_pred = deci_tree.predict(X_test)
    acc.append(accuracy_score(y_test,y_pred))
deci_random = sum(acc)/len(acc)
deci_random
# Out:
# 0.7098958333333334

# %%
#random subsampling
#naive bayse
acc_naive = []
nb_random = GaussianNB()
for i in range(10):
    X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.25,random_state = i+1)
    nb_random.fit(X_train,y_train)
    y_pred = nb_random.predict(X_test)
    acc_naive.append(accuracy_score(y_test,y_pred))
nb_random = sum(acc_naive)/len(acc_naive)
nb_random
# Out:
# 0.7557291666666666

# %%
#random subsampling
#knn
acc_knn = []
knn_random = KNeighborsClassifier()
for i in range(10):
    X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.25,random_state = i+1)
    knn_random.fit(X_train,y_train)
    y_pred = knn_random.predict(X_test)
    acc_knn.append(accuracy_score(y_test,y_pred))
knn_random = sum(acc_knn)/len(acc_knn)
knn_random
# Out:
# 0.7260416666666666

# %%
#Cross validation
from sklearn.model_selection import KFold,StratifiedKFold,LeaveOneOut
from sklearn.model_selection import cross_val_score

# %%
#Cross validation
#Decision Tree
kf = KFold(n_splits = 10)
deci_cross = cross_val_score(deci_tree,X,y,cv = kf)
deci_cross = deci_cross.mean()
print("Accuracy of decision tree on cross validation : ",deci_cross*100)
# Out:
# Accuracy of decision tree on cross validation :  70.96377306903624

# %%
#Cross validation
#Naive Bayse
loo = LeaveOneOut()
nb_cross = cross_val_score(nb,X,y,cv = loo)
nb_cross = deci_cross.mean()
print("Accuracy of decision tree on cross validation : ",nb_cross*100)
# Out:
# Accuracy of decision tree on cross validation :  70.96377306903624

# %%
#Cross validation
#knn
skf = StratifiedKFold(n_splits = 10)
knn_cross = cross_val_score(knn,X,y,cv = skf)
knn_cross = knn_cross.mean()
print("Accuracy of decision tree on cross validation : ",knn_cross*100)
# Out:
# Accuracy of decision tree on cross validation :  73.82433356117566

# %%
#Comparing accuracies
#Hold out method
print("Accuracy of decision tree in hold out method : ",deci_score * 100 ,"%\n" )
print("Accuracy of naive bayse in hold out method : ",nb_score * 100 ,"%\n" )
print("Accuracy of knn in hold out method : ",knn_score * 100 ,"%\n" )
# Out:
# Accuracy of decision tree in hold out method :  68.75 %
#
# Accuracy of naive bayse in hold out method :  73.4375 %
#
# Accuracy of knn in hold out method :  68.22916666666666 %

# %%
#Random sampling
print("Accuracy of decision tree in random sub sampling method : ",deci_random * 100 ,"%\n" )
print("Accuracy of naive bayse in random sub sampling method : ",nb_random * 100 ,"%\n" )
print("Accuracy of knn in random sub sampling method : ",knn_random * 100 ,"%\n" )
# Out:
# Accuracy of decision tree in random sub sampling method :  70.98958333333334 %
#
# Accuracy of naive bayse in random sub sampling method :  75.57291666666666 %
#
# Accuracy of knn in random sub sampling method :  72.60416666666666 %

# %%
#Cross Validation
print("Accuracy of decision tree in cross validation method : ",deci_cross * 100 ,"%\n" )
print("Accuracy of naive bayse in cross validation method : ",nb_cross * 100 ,"%\n" )
print("Accuracy of knn in cross validation method : ",knn_cross * 100 ,"%\n" )
# Out:
# Accuracy of decision tree in cross validation method :  70.96377306903624 %
#
# Accuracy of naive bayse in cross validation method :  70.96377306903624 %
#
# Accuracy of knn in cross validation method :  73.82433356117566 %
